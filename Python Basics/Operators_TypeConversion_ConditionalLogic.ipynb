# %%
# Arithmetic and Comparisoon Operators

a = 10
b = 3

# Arithmetic
print("Addition: ", a + b)
print("Subtraction: ", a - b)
print("Multiplication: ", a * b)
print("Division: ", a / b)
print("Floor Division: ", a // b)
print("Modulus: ", a % b)
print("Exponent: ", a ** b)

# Comparison
print("Equal: ", a == b)
print("Not Equal: ", a != b)
print("Greater Than: ", a > b)
print("Less Than: ", a < b)
print("Greater or Equal: ", a >= b)
print("Less or Equal: ", a <= b)
# Out:
# Addition:  13
# Subtraction:  7
# Multiplication:  30
# Division:  3.3333333333333335
# Floor Division:  3
# Modulus:  1
# Exponent:  1000
# Equal:  False
# Not Equal:  True
# Greater Than:  True
# Less Than:  False
# Greater or Equal:  True
# Less or Equal:  False

# %%
# Write a program that compares two numbers and tells which one is larger or if they are equal

# Ask the user for two numbers
num1 = float(input("Enter a number: "))
num2 = float(input("Enter another number: "))

# compares the two numbers
if num1 > num2:
    print(f"{num1} is greater than {num2}.")
elif num2 > num1:
    print(f"{num2} is greater than {num1}.")
else:
    print(f"Both numbers are equal.")
# Out:
# Enter a number:  10
# Enter another number:  20
# 20.0 is greater than 10.0.

# %%
# 2. Logical Operators

x = True
y = False

print("AND:", x and y)
print("OR:", x or y)
print("NOT:", not x)
# Out:
# AND: False
# OR: True
# NOT: False

# %%
# Challenge: write a short program that checks if someone's age is between 18 and 60

# Ask the user for their age
age = int(input("Enter your age: "))

# Checks if the user age is between 18 an d60
if age >= 18 and age <= 60:
    print("You are an adult in working range.")
else:
    print("You are either too young or retired.")
# Out:
# Enter your age:  24
# You are an adult in working range.

# %%
# 3. Conditional Statements

temperature = float(input("Enter temperature: "))

if temperature > 30:
    print("It is hot outside.")
elif temperature >= 20:
    print("Nice and warm.")
else: 
    print("A bit chilly.")
# Out:
# Enter temperature:  20
# Nice and warm.

# %%
# 4. Type Conversion and Input Handling

# Input is always a string
num1 = input("Enter a number: ")
num2 = input("Enter another number: ")

# Convert to int
total = int(num1) + int(num2)
print("The sum is:", total)
# Out:
# Enter a number:  20
# Enter another number:  20
# The sum is: 40

# %%
# 5. Mini Project - Grade Evaluator

# Write a program that asks the user for their score (0-100) and print their grade letter.

# Ask for the user score
score = int(input("Enter your score: "))

if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
elif score >= 60:
    grade = "D"
else:
    grade = "F"

print(f"Your grade is {grade}")
# Out:
# Enter your score:  90
# Your grade is A
